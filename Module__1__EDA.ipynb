# %% [markdown]
# <a href="https://colab.research.google.com/github/HARSHA0232/EDA-DIGTAL-ASSIGNMENT---1-/blob/main/Module__1__EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 1: Introduction to Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Student Details
# **Name**: BAJJURI HARSHA VARDHAN
# **Registration Number**: 21BDS0232
# **DIGITAL ASSIGNMENT - 1**

# %% [markdown]
# ## Step 1: Load the Dataset

# %%
# Importing the necessary libraries
import pandas as pd

# Load the dataset from the new GitHub link
url = 'https://github.com/HARSHA0232/EDA-DIGTAL-ASSIGNMENT---1-/blob/main/student-mat.csv?raw=true'
data = pd.read_csv(url)

# Display the first few rows of the dataset
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Step 2: Explore the Dataset
# ### Dimensions of the Dataset

# %%
data.shape
# Out:
# (395, 33)

# %% [markdown]
# ### Summary of the Dataset

# %%
data.describe(include='all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  393  395.000000     394     394     395  395.000000
# unique      2    2         NaN       3       2       3         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     304     280     348         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.749367
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.094735
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  ...      famrel    freetime       goout  \
# count   395.000000    395    395  ...  395.000000  395.000000  395.000000
# ...

# %% [markdown]
# ### Missing Values Count

# %%
data.isnull().sum()
# Out:
# school        0
# sex           2
# age           0
# address       1
# famsize       1
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     2
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# ### Numerical Summary

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# ##Summary
#
# This notebook begins by loading the dataset, followed by an assessment of missing values using data.isnull().sum(). It then examines the dataset's structure with data.shape. Descriptive statistics are provided, both for all columns using data.describe(include='all') and specifically for numerical columns with data.describe(). These steps lay the foundation for deeper analysis, which will be carried out in subsequent sections.
